# %% [markdown]
# # Probability exercises

# %% [markdown]
# ### Exercise 1
#
# Two unbiased dice are thrown once and the total score is observed. Use a simulation to find the estimated probability that the total score is even or greater than 7
#
# We could use a mathematical equation to solve this or we can run the experiment many times, and then count the number of times where the score is even or greater than 7
#
# -Run the experiment 1000 times (roll 2 dice 1000 times, and sum the result)
#
# -Keep track of the number of times that the sum was either greater than 7 or an even number
#
# -Divide the number from step 2 by the number of iterations (1000)

# %%
import random
import numpy as np

#Funtion to roll the dice.

def roll_the_dice(n_simulations = 1000):
    count = 0
    
    #each iteration of the for loop is trial
    for i in range(n_simulations):
        
        #roll each die
        die1 = random.randint(1,6)
        die2 = random.randint(1,6)
        
        #Sum the values to get the score
        score = die1 + die2
        
        #decide if we should add it to the count:
        if score % 2 == 0 or score > 7 :
            count+= 1
    
    return count/n_simulations
string = 'The probability of rolling an even number or greater than 7 is:'

print(string, np.round(roll_the_dice()*100, 2), '%')
# Out:
# The probability of rolling an even number or greater than 7 is: 66.2 %

# %% [markdown]
# ### Exercise 2
#
# A box contains 10 white balls, 20 reds and 30 greens. Draw 5 balls with replacement. What is the probability that:
#
# a. 3 white or 2 red
#
# b. All 5 are the same color
#
#
# We will use the same system here. We will pick our balls during each round and count the number of times that:
#
# a. 3 white or 2 red
#
# b. All 5 are the same color.

# %%
import numpy as np
import random
random.seed(100)

balls = {}

for i in range(60): 
    if i < 10:     
       balls[i] = 'colour_white' 
    elif i > 9 and i < 30: 
        balls[i] = 'colour_red'
    else:
        balls[i] = 'colour_green'  

        
        
#Initialize important variables
n_simulations = 1000
ejer_a = 0
ejer_b = 0

for i in range(n_simulations):
   
    
    #make a list of the colors that we choose
       
    for i in range(5):
        bolillero.append(balls[random.randint(0,59)])
        
    #Convert it to a numpy array
    bolillero = np.array(bolillero)
    #find the number of each taht we picked
    white = sum(bolillero[i] == 'colour_white')
    red = sum(bolillero[i] == 'colour_red')
    green = sum(bolillero[i] == 'colour_green')


    #Keep track if the combination met the criteria """
    if white == 3 and red == 2:
        ejer_a += 1
    
    if red == 5 or white == 5 or green ==5:
       ejer_b +=1

print('The probability of 3 white and 2 red is:', round(ejer_a/n_simulations*100,2),'%')
print()
print('The probability of all the same color is:', round(ejer_b/n_simulations*100,2),'%')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /workspace/probability-exercises-project-in-python/notebook/problems.ipynb Cell 5' in <cell line: 22>()
#      <a href='vscode-notebook-cell://marfurt1-probabilityexe-limrot5t3ix.ws-us46.gitpod.io/workspace/probability-exercises-project-in-python/notebook/problems.ipynb#ch0000004vscode-remote?line=21'>22</a> for i in range(n_simulations):
#      <a href='vscode-notebook-cell://marfurt1-probabilityexe-limrot5t3ix.ws-us46.gitpod.io/workspace/probability-exercises-project-in-python/notebook/problems.ipynb#ch0000004vscode-remote?line=22'>23</a>
#      <a href='vscode-notebook-cell://marfurt1-probabilityexe-limrot5t3ix.ws-us46.gitpod.io/workspace/probability-exercises-project-in-python/notebook/problems.ipynb#ch0000004vscode-remote?line=23'>24</a>     #make a list of the colors that we choose
#      <a href='vscode-notebook-cell://marfurt1-probabilityexe-limrot5t3ix.ws-us46.gitpod.io/workspace/probability-exercises-project-in-python/notebook/problems.ipynb#ch0000004vscode-remote?line=25'>26</a>     for i in range(5):
# ---> <a href='vscode-notebook-cell://marfurt1-probabilityexe-limrot5t3ix.ws-us46.gitpod.io/workspace/probability-exercises-project-in-python/notebook/problems.ipynb#ch0000004vscode-remote?line=26'>27</a>         bolillero.append(balls[random.randint(0,59)])
#      <a href='vscode-notebook-cell://marfurt1-probabilityexe-limrot5t3ix.ws-us46.gitpod.io/workspace/probability-exercises-project-in-python/notebook/problems.ipynb#ch0000004vscode-remote?line=28'>29</a>     #Convert it to a numpy array
#      <a href='vscode-notebook-cell://marfurt1-probabilityexe-limrot5t3ix.ws-us46.gitpod.io/workspace/probability-exercises-project-in-python/notebook/problems.ipynb#ch0000004vscode-remote?line=29'>30</a>     bolillero = np.array(bolillero)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'append'
